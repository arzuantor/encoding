# %%
import pandas as pd

# %%
df=pd.read_csv("/content/Sample - Superstore - Sample - Superstore.csv")

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
ds=df[["Segment","City","State","Ship Mode","Region","Category"]]

# %%
ds.head(1)
# Out:
#     Segment       City     State     Ship Mode Region   Category
# 0  Consumer  Henderson  Kentucky  Second Class  South  Furniture

# %%
df1 = ds.copy()
df2 = ds.copy()
df3 = ds.copy()
df4 = ds.copy()
df5 = ds.copy()

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, OrdinalEncoder

# %% [markdown]
# #LableEncoding

# %%
le=LabelEncoder()
df1['Category']=le.fit_transform(df1['Category'])
df1
# Out:
#         Segment             City       State       Ship Mode Region  Category
# 0      Consumer        Henderson    Kentucky    Second Class  South         0
# 1      Consumer        Henderson    Kentucky    Second Class  South         0
# 2     Corporate      Los Angeles  California    Second Class   West         1
# 3      Consumer  Fort Lauderdale     Florida  Standard Class  South         0
# 4      Consumer  Fort Lauderdale     Florida  Standard Class  South         1
# ...         ...              ...         ...             ...    ...       ...
# 9989   Consumer            Miami     Florida    Second Class  South         0
# 9990   Consumer       Costa Mesa  California  Standard Class   West         0
# 9991   Consumer       Costa Mesa  California  Standard Class   West         2
# 9992   Consumer       Costa Mesa  California  Standard Class   West         1
# 9993   Consumer      Westminster  California    Second Class   West         1
#
# [9994 rows x 6 columns]

# %%
df1['Category'].value_counts()
# Out:
# Category
# 1    6026
# 0    2121
# 2    1847
# Name: count, dtype: int64

# %%
df2.head(1)
# Out:
#     Segment       City     State     Ship Mode Region   Category
# 0  Consumer  Henderson  Kentucky  Second Class  South  Furniture
